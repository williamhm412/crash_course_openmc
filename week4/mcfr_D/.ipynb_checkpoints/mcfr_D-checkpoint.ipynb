# %% [markdown]
# # MCFR-D
# *Data taken from the mcfr.xslx spreadsheet in the repo (originally from TerraPower Report)*

# %%
import openmc

# %% [markdown]
# ## Materials

# %%
## fuel material specifications
U_atom_percent  = 0.25*(1/3)
U_enrichment    = 19.75 # %U235
Cl_atom_percent = 0.75*(1/3) + 0.5*(2/3)
Cl_enrichment   = 99.0 # %Cl37
Na_atom_percent = 0.5*(2/3)

fuel_T          = 695 + 273.15 # K
A               = 4212.6
B               = 1.0686
fuel_density    = (A - B*fuel_T ) * (1000/1) * ((1/100)**3) # g / cc

## clad material specifications
clad_elements = ["Ni", "Cr", "Mo", "Fe", "Nb", "Ta", "Co", "Mn", "Si", "Al", "Ti", "C", "P", "S"]
clad_element_weight_percents = [0.58, 0.2142, 0.09, 0.05, 0.01825, 0.01825, 0.01, 0.005, 0.005, 0.004, 0.004, 0.001, 0.00015, 0.00015]
clad_T = 695 + 273.15 # K
clad_density = 8.3 # g / cc

## reflector material specifications
reflector_T = 695 + 273.15 # K
reflector_density = 3.6 # g / cc
reflector_atom_percent_Mg = 0.5
reflector_atom_percent_O = 0.5

# %%
fuel = openmc.Material(name="fuel")
fuel.add_element('U', U_atom_percent, percent_type='ao', enrichment=U_enrichment)
fuel.add_element('Cl', Cl_atom_percent, percent_type='ao', enrichment=Cl_enrichment, enrichment_target='Cl37', enrichment_type='wo')
fuel.add_element('Na', Na_atom_percent, percent_type='ao')
fuel.set_density('g/cm3', fuel_density) # set density
fuel.temperature = fuel_T

clad = openmc.Material(name="clad")
for i in range(len(clad_elements)):
    clad.add_element(clad_elements[i], clad_element_weight_percents[i], percent_type='wo')
clad.set_density('g/cm3', clad_density)
clad.temperature = clad_T

reflector = openmc.Material(name="reflector")
reflector.add_element('Mg', reflector_atom_percent_Mg, percent_type='ao')
reflector.add_element('O',  reflector_atom_percent_O,  percent_type='ao')
reflector.set_density('g/cm3', reflector_density)
reflector.temperature = reflector_T
# Out:
# /home/william/miniconda3/envs/openmc_env/lib/python3.13/site-packages/openmc/material.py:805: UserWarning: A uranium enrichment of 19.75 was given for Material ID="1". OpenMC assumes the U234/U235 mass ratio is constant at 0.008, which is only valid at low enrichments. Consider setting the isotopic composition manually for enrichments over 5%.
#   warnings.warn(msg)

# %%
materials = openmc.Materials([fuel, clad, reflector])
materials.export_to_xml()

# %% [markdown]
# ## Surfaces

# %%
cylinder_radii = [95.0, 96.0, 185.0]
zplane_offsets = [-265.0, -176.0, -175.0, 175.0, 176.0, 265.0]

# %%
c1  = openmc.ZCylinder(r=cylinder_radii[0])
c2  = openmc.ZCylinder(r=cylinder_radii[1])
c3  = openmc.ZCylinder(r=cylinder_radii[2], boundary_type='vacuum')
z_3 = openmc.ZPlane(z0=  zplane_offsets[0], boundary_type='vacuum')
z_2 = openmc.ZPlane(z0=  zplane_offsets[1])
z_1 = openmc.ZPlane(z0=  zplane_offsets[2])
z1  = openmc.ZPlane(z0=  zplane_offsets[3])
z2  = openmc.ZPlane(z0=  zplane_offsets[4])
z3  = openmc.ZPlane(z0=  zplane_offsets[5], boundary_type='vacuum')

# %% [markdown]
# ## Cells

# %%
bottom_reflector_region = +z_3 & -z_2 & -c3
top_reflector_region    = +z2 & -z3 & -c3
radial_reflector_region = +z_2 & -z2 & +c2 & -c3
bottom_clad_region      = +z_2 & -z_1 & -c2
top_clad_region         = +z1 & -z2 & -c2
axial_clad_region       = +z_1 & -z1 & +c1 & -c2
total_core_region       = +z_1 & -z1 & -c1

# %%
bottom_reflector = openmc.Cell(fill = reflector, region = bottom_reflector_region)
top_reflector    = openmc.Cell(fill = reflector, region = top_reflector_region)
radial_reflector = openmc.Cell(fill = reflector, region = radial_reflector_region)
bottom_clad      = openmc.Cell(fill = clad,      region = bottom_clad_region)
top_clad         = openmc.Cell(fill = clad,      region = top_clad_region)
axial_clad       = openmc.Cell(fill = clad,      region = axial_clad_region)
total_core       = openmc.Cell(fill = fuel,      region = total_core_region)

# %%
root_universe = openmc.Universe(cells=[bottom_reflector, top_reflector, radial_reflector, bottom_clad, top_clad, axial_clad, total_core])
geometry = openmc.Geometry()
geometry.root_universe = root_universe
geometry.export_to_xml()

# %% [markdown]
# ## Visualization
# [OpenMC Documentation on Visualization](https://docs.openmc.org/en/stable/usersguide/plots.html)

# %%
## Inline plots
# root_universe.plot(width=(400, 400), basis='xy')
# root_universe.plot(width=(400, 550), basis='xz')

# %%
# xy basis png plot
xy_png          = openmc.Plot(name="xy_png")
xy_png.basis    = 'xy'
xy_png.origin   = (0, 0, 0)
xy_png.width    = (400, 400)
xy_png.pixels   = (700, 700)
xy_png.color_by = 'material'
xy_png.filename = 'xy_png'

# xz basis png plot
xz_png          = openmc.Plot(name="xz_png")
xz_png.basis    = 'xz'
xz_png.origin   = (0, 0, 0)
xz_png.width    = (400, 550)
xz_png.pixels   = (700, 700)
xz_png.color_by = 'material'
xz_png.filename = 'xz_png'

# voxel plot
voxel_plot          = openmc.Plot(name="voxel_plot")
voxel_plot.type     = 'voxel'
voxel_plot.origin   = (0,0,0)
voxel_plot.width    = (400, 400, 550)
voxel_plot.pixels   = (400, 400, 550)
voxel_plot.filename = 'voxel_plot'

# %%
visualization = openmc.Plots([xy_png, xz_png, voxel_plot])
visualization.export_to_xml()

# %% [markdown]
# ## Settings

# %%
point = openmc.stats.Point((0, 0, 0))
source = openmc.IndependentSource(space=point)

settings = openmc.Settings()
settings.run_mode = 'eigenvalue'
settings.source = source
settings.batches = 150
settings.inactive = 20
settings.particles = 1000

settings.temperature = {'method': 'interpolation'}

# %%
settings.export_to_xml()

# %% [markdown]
# ## Run File

# %%
## Generate Plots
openmc.plot_geometry()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-11-16 02:02:49
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading chain file:
#  /home/william/openmc/fundamental_nuclear_data/depletion_chains/chain_endfb71_sfr
#  .xml...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 1
# Plot file: xy_png.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:  400  400
# Coloring: Materials
# Basis: XY
# Pixels: 700 700
#
# Plot ID: 2
# Plot file: xz_png.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:  400  550
# Coloring: Materials
# Basis: XZ
# Pixels: 700 700
#
# Plot ID: 3
# Plot file: voxel_plot.h5
# Universe depth: -1
# Plot Type: Voxel
# Origin: 0 0 0
# Width:  400  400  550
# Coloring: Cells
# Voxels: 400 400 550
#
#  Processing plot 1: xy_png.png...
#  Processing plot 2: xz_png.png...
#  Processing plot 3: voxel_plot.h5...

# %%
## Run data
openmc.run()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.2
#      Commit Hash | e23760b0264c66fb7bb373aa0596801e5209d920
#        Date/Time | 2025-11-16 02:02:59
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading chain file:
#  /home/william/openmc/fundamental_nuclear_data/depletion_chains/chain_endfb71_sfr
#  .xml...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading U234 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/U234.h5
#  Reading U235 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/U235.h5
#  Reading U238 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/U238.h5
#  Reading U236 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/U236.h5
#  Reading Cl35 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Cl35.h5
#  Reading Cl37 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Cl37.h5
#  Reading Na23 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Na23.h5
#  Reading Ni58 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ni58.h5
#  Reading Ni60 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ni60.h5
#  Reading Ni61 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ni61.h5
#  Reading Ni62 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ni62.h5
#  Reading Ni64 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ni64.h5
#  Reading Cr50 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Cr50.h5
#  Reading Cr52 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Cr52.h5
#  Reading Cr53 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Cr53.h5
#  Reading Cr54 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Cr54.h5
#  Reading Mo92 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo92.h5
#  Reading Mo94 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo94.h5
#  Reading Mo95 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo95.h5
#  Reading Mo96 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo96.h5
#  Reading Mo97 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo97.h5
#  Reading Mo98 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo98.h5
#  Reading Mo100 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mo100.h5
#  Reading Fe54 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Fe54.h5
#  Reading Fe56 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Fe56.h5
#  Reading Fe57 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Fe57.h5
#  Reading Fe58 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Fe58.h5
#  Reading Nb93 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Nb93.h5
#  Reading Ta180 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ta180.h5
#  Reading Ta181 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ta181.h5
#  Reading Co59 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Co59.h5
#  Reading Mn55 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mn55.h5
#  Reading Si28 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Si28.h5
#  Reading Si29 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Si29.h5
#  Reading Si30 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Si30.h5
#  Reading Al27 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Al27.h5
#  Reading Ti46 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ti46.h5
#  Reading Ti47 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ti47.h5
#  Reading Ti48 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ti48.h5
#  Reading Ti49 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ti49.h5
#  Reading Ti50 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Ti50.h5
#  Reading C0 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/C0.h5
#  Reading P31 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/P31.h5
#  Reading S32 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/S32.h5
#  Reading S33 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/S33.h5
#  Reading S34 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/S34.h5
#  Reading S36 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/S36.h5
#  Reading Mg24 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mg24.h5
#  Reading Mg25 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mg25.h5
#  Reading Mg26 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/Mg26.h5
#  Reading O16 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/O16.h5
#  Reading O17 from
#  /home/william/openmc/fundamental_nuclear_data/x_section_data/endfb-vii.1-hdf5/ne
#  utron/O17.h5
#  Minimum neutron data temperature: 900 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for U235
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.25822
#         2/1    1.12209
#         3/1    1.14393
#         4/1    1.08838
#         5/1    1.03977
#         6/1    1.05678
#         7/1    1.07302
#         8/1    1.05608
#         9/1    1.04351
#        10/1    1.02667
#        11/1    1.06492
#        12/1    1.02967
#        13/1    1.07922
#        14/1    1.04173
#        15/1    1.03025
#        16/1    0.99059
#        17/1    1.12858
#        18/1    1.06095
#        19/1    1.09474
#        20/1    1.05481
#        21/1    1.07819
#        22/1    1.01749    1.04784 +/- 0.03035
#        23/1    1.04469    1.04679 +/- 0.01756
#        24/1    1.02280    1.04079 +/- 0.01379
#        25/1    1.04124    1.04088 +/- 0.01068
#        26/1    1.02569    1.03835 +/- 0.00908
#        27/1    1.06570    1.04226 +/- 0.00861
#        28/1    1.03438    1.04127 +/- 0.00752
#        29/1    0.98478    1.03499 +/- 0.00913
#        30/1    1.10820    1.04232 +/- 0.01097
#        31/1    1.11835    1.04923 +/- 0.01209
#        32/1    1.05925    1.05006 +/- 0.01107
#        33/1    1.04984    1.05005 +/- 0.01018
#        34/1    1.03987    1.04932 +/- 0.00946
#        35/1    1.11399    1.05363 +/- 0.00980
#        36/1    1.09547    1.05625 +/- 0.00953
#        37/1    1.10149    1.05891 +/- 0.00934
#        38/1    1.07329    1.05971 +/- 0.00885
#        39/1    1.08709    1.06115 +/- 0.00849
#        40/1    0.98055    1.05712 +/- 0.00901
#        41/1    0.98819    1.05384 +/- 0.00917
#        42/1    1.06457    1.05432 +/- 0.00876
#        43/1    1.10251    1.05642 +/- 0.00863
#        44/1    1.07270    1.05710 +/- 0.00829
#        45/1    1.05072    1.05684 +/- 0.00796
#        46/1    1.04331    1.05632 +/- 0.00766
#        47/1    1.12390    1.05882 +/- 0.00779
#        48/1    1.05290    1.05861 +/- 0.00750
#        49/1    1.00313    1.05670 +/- 0.00749
#        50/1    1.09881    1.05810 +/- 0.00737
#        51/1    1.09253    1.05921 +/- 0.00722
#        52/1    1.03949    1.05860 +/- 0.00701
#        53/1    1.09816    1.05980 +/- 0.00690
#        54/1    1.04822    1.05946 +/- 0.00670
#        55/1    1.03540    1.05877 +/- 0.00655
#        56/1    1.04912    1.05850 +/- 0.00637
#        57/1    1.11719    1.06009 +/- 0.00639
#        58/1    1.04485    1.05969 +/- 0.00624
#        59/1    1.05708    1.05962 +/- 0.00607
#        60/1    1.06551    1.05977 +/- 0.00592
#        61/1    1.00269    1.05837 +/- 0.00594
#        62/1    1.07400    1.05875 +/- 0.00581
#        63/1    1.07900    1.05922 +/- 0.00569
#        64/1    1.09524    1.06004 +/- 0.00562
#        65/1    0.99553    1.05860 +/- 0.00568
#        66/1    1.10202    1.05955 +/- 0.00563
#        67/1    1.07393    1.05985 +/- 0.00552
#        68/1    1.05991    1.05985 +/- 0.00541
#        69/1    1.02171    1.05908 +/- 0.00535
#        70/1    1.10792    1.06005 +/- 0.00533
#        71/1    1.03325    1.05953 +/- 0.00525
#        72/1    1.02671    1.05890 +/- 0.00519
#        73/1    1.12441    1.06013 +/- 0.00524
#        74/1    1.03630    1.05969 +/- 0.00516
#        75/1    1.06414    1.05977 +/- 0.00507
#        76/1    1.02730    1.05919 +/- 0.00501
#        77/1    1.03475    1.05876 +/- 0.00494
#        78/1    1.04925    1.05860 +/- 0.00486
#        79/1    1.07512    1.05888 +/- 0.00478
#        80/1    1.07123    1.05908 +/- 0.00470
#        81/1    1.04425    1.05884 +/- 0.00463
#        82/1    1.09744    1.05946 +/- 0.00460
#        83/1    1.01211    1.05871 +/- 0.00459
#        84/1    1.03813    1.05839 +/- 0.00453
#        85/1    1.02950    1.05795 +/- 0.00448
#        86/1    1.04993    1.05782 +/- 0.00441
#        87/1    1.09836    1.05843 +/- 0.00439
#        88/1    1.03839    1.05813 +/- 0.00433
#        89/1    1.06439    1.05823 +/- 0.00427
#        90/1    1.10359    1.05887 +/- 0.00426
#        91/1    1.02577    1.05841 +/- 0.00422
#        92/1    1.07345    1.05862 +/- 0.00417
#        93/1    1.03468    1.05829 +/- 0.00413
#        94/1    1.05387    1.05823 +/- 0.00407
#        95/1    1.05934    1.05824 +/- 0.00402
#        96/1    1.04159    1.05802 +/- 0.00397
#        97/1    0.99780    1.05724 +/- 0.00399
#        98/1    1.06835    1.05738 +/- 0.00395
#        99/1    0.98294    1.05644 +/- 0.00401
#       100/1    1.05284    1.05640 +/- 0.00396
#       101/1    1.07107    1.05658 +/- 0.00391
#       102/1    1.01156    1.05603 +/- 0.00390
#       103/1    1.01995    1.05559 +/- 0.00388
#       104/1    1.06728    1.05573 +/- 0.00384
#       105/1    1.10492    1.05631 +/- 0.00383
#       106/1    0.98219    1.05545 +/- 0.00389
#       107/1    1.05296    1.05542 +/- 0.00384
#       108/1    1.02296    1.05505 +/- 0.00382
#       109/1    1.13870    1.05599 +/- 0.00389
#       110/1    1.07447    1.05620 +/- 0.00385
#       111/1    1.01230    1.05572 +/- 0.00384
#       112/1    1.01964    1.05532 +/- 0.00382
#       113/1    1.09784    1.05578 +/- 0.00380
#       114/1    1.00834    1.05528 +/- 0.00380
#       115/1    1.07743    1.05551 +/- 0.00376
#       116/1    1.14671    1.05646 +/- 0.00384
#       117/1    1.04612    1.05635 +/- 0.00380
#       118/1    1.08951    1.05669 +/- 0.00378
#       119/1    1.03052    1.05643 +/- 0.00375
#       120/1    1.02182    1.05608 +/- 0.00373
#       121/1    1.09106    1.05643 +/- 0.00371
#       122/1    1.04719    1.05634 +/- 0.00367
#       123/1    1.14057    1.05715 +/- 0.00373
#       124/1    1.06005    1.05718 +/- 0.00369
#       125/1    1.09594    1.05755 +/- 0.00368
#       126/1    1.08501    1.05781 +/- 0.00365
#       127/1    1.05571    1.05779 +/- 0.00362
#       128/1    1.06138    1.05782 +/- 0.00358
#       129/1    1.04438    1.05770 +/- 0.00355
#       130/1    1.08506    1.05795 +/- 0.00353
#       131/1    1.02636    1.05766 +/- 0.00351
#       132/1    1.04448    1.05755 +/- 0.00348
#       133/1    1.06571    1.05762 +/- 0.00345
#       134/1    1.07169    1.05774 +/- 0.00342
#       135/1    1.02057    1.05742 +/- 0.00341
#       136/1    1.03521    1.05723 +/- 0.00338
#       137/1    0.98856    1.05664 +/- 0.00340
#       138/1    1.02505    1.05637 +/- 0.00338
#       139/1    1.09642    1.05671 +/- 0.00337
#       140/1    1.03681    1.05654 +/- 0.00335
#       141/1    1.10102    1.05691 +/- 0.00334
#       142/1    1.05586    1.05690 +/- 0.00331
#       143/1    1.08738    1.05715 +/- 0.00330
#       144/1    1.09796    1.05748 +/- 0.00329
#       145/1    1.03802    1.05732 +/- 0.00326
#       146/1    1.11152    1.05775 +/- 0.00327
#       147/1    1.01577    1.05742 +/- 0.00326
#       148/1    1.07610    1.05757 +/- 0.00323
#       149/1    1.04695    1.05749 +/- 0.00321
#       150/1    1.09891    1.05781 +/- 0.00320
#  Creating state point statepoint.150.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3378e+01 seconds
#    Reading cross sections          = 1.2565e+01 seconds
#  Total time in simulation          = 6.7049e+00 seconds
#    Time in transport only          = 6.6536e+00 seconds
#    Time in inactive batches        = 1.1400e+00 seconds
#    Time in active batches          = 5.5649e+00 seconds
#    Time synchronizing fission bank = 1.5296e-02 seconds
#      Sampling source sites         = 1.4206e-02 seconds
#      SEND/RECV source sites        = 1.0077e-03 seconds
#    Time accumulating tallies       = 7.4997e-05 seconds
#    Time writing statepoints        = 4.8532e-03 seconds
#  Total time for finalization       = 1.0550e-06 seconds
#  Total time elapsed                = 2.0117e+01 seconds
#  Calculation Rate (inactive)       = 17544.3 particles/second
#  Calculation Rate (active)         = 23360.6 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.05682 +/- 0.00301
#  k-effective (Track-length)  = 1.05781 +/- 0.00320
#  k-effective (Absorption)    = 1.05014 +/- 0.00286
#  Combined k-effective        = 1.05339 +/- 0.00241
#  Leakage Fraction            = 0.01909 +/- 0.00038

# %% [markdown]
# ## Convert Voxel plot to vtk
# Requirements for viewing voxel plot:
# - run this code to convert the voxel file from hdf5 format to vtk format
# - intall the vtk package in your python openmc-env by running ```conda install vtk```
# - install praview (or something similar)
# - navigate to this directory and open 'voxel_plot.vti' file in paraview (or a similar program)

# %%
openmc.voxel_to_vtk(voxel_file = f'{voxel_plot.filename}.h5', output = voxel_plot.filename)
# Out:
# 'voxel_plot.vti'
